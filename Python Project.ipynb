# %%
# %%writefile csv_loader.py
def load_csv_with_generated_ids(file_path):
    data = {}
    with open(file_path, 'r') as file:
        rows = file.readlines()
        header = rows[0].strip().split(',')  # Extract header from the first row
        
        for index, row in enumerate(rows[1:], start=1):  # Start ID generation from 1
            row = row.strip().split(',')    
            # Create a dictionary for each row
            values = {header[i]: row[i] for i in range(len(row))}  
            data[str(index)] = values
    
    return data
# Out:
# Overwriting csv_loader.py

# %%
from csv_loader import load_csv_with_generated_ids
file_path = r"C:\Users\USER\Downloads\heart+failure+clinical+records\heart_failure_clinical_records_dataset.csv"
csv_data = load_csv_with_generated_ids(file_path)

# %%
from csv_loader import load_csv_with_generated_ids 
csv_data = load_csv_with_generated_ids(file_path)
file_path=r"C:\Users\USER\Downloads\heart+failure+clinical+records\heart_failure_clinical_records_dataset.csv"
for age,patients_details in csv_data.items():
     print(f"{age}:{patients_details}") #Displays the entire data set
        #print(details["time"]
# Out:
# 1:{'age': '75', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '1', 'platelets': '265000', 'serum_creatinine': '1.9', 'serum_sodium': '130', 'sex': '1', 'smoking': '0', 'time': '4', 'DEATH_EVENT': '1'}
# 2:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '7861', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.1', 'serum_sodium': '136', 'sex': '1', 'smoking': '0', 'time': '6', 'DEATH_EVENT': '1'}
# 3:{'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '146', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '162000', 'serum_creatinine': '1.3', 'serum_sodium': '129', 'sex': '1', 'smoking': '1', 'time': '7', 'DEATH_EVENT': '1'}
# 4:{'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '111', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '210000', 'serum_creatinine': '1.9', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '7', 'DEATH_EVENT': '1'}
# 5:{'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '160', 'diabetes': '1', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '327000', 'serum_creatinine': '2.7', 'serum_sodium': '116', 'sex': '0', 'smoking': '0', 'time': '8', 'DEATH_EVENT': '1'}
# 6:{'age': '90', 'anaemia': '1', 'creatinine_phosphokinase': '47', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '1', 'platelets': '204000', 'serum_creatinine': '2.1', 'serum_sodium': '132', 'sex': '1', 'smoking': '1', 'time': '8', 'DEATH_EVENT': '1'}
# 7:{'age': '75', 'anaemia': '1', 'creatinine_phosphokinase': '246', 'diabetes': '0', 'ejection_fraction': '15', 'high_blood_pressure': '0', 'platelets': '127000', 'serum_creatinine': '1.2', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '10', 'DEATH_EVENT': '1'}
# 8:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '315', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '454000', 'serum_creatinine': '1.1', 'serum_sodium': '131', 'sex': '1', 'smoking': '1', 'time': '10', 'DEATH_EVENT': '1'}
# 9:{'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '157', 'diabetes': '0', 'ejection_fraction': '65', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.5', 'serum_sodium': '138', 'sex': '0', 'smoking': '0', 'time': '10', 'DEATH_EVENT': '1'}
# 10:{'age': '80', 'anaemia': '1', 'creatinine_phosphokinase': '123', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '1', 'platelets': '388000', 'serum_creatinine': '9.4', 'serum_sodium': '133', 'sex': '1', 'smoking': '1', 'time': '10', 'DEATH_EVENT': '1'}
# 11:{'age': '75', 'anaemia': '1', 'creatinine_phosphokinase': '81', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '368000', 'serum_creatinine': '4', 'serum_sodium': '131', 'sex': '1', 'smoking': '1', 'time': '10', 'DEATH_EVENT': '1'}
# 12:{'age': '62', 'anaemia': '0', 'creatinine_phosphokinase': '231', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '253000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '10', 'DEATH_EVENT': '1'}
# 13:{'age': '45', 'anaemia': '1', 'creatinine_phosphokinase': '981', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '136000', 'serum_creatinine': '1.1', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '11', 'DEATH_EVENT': '1'}
# 14:{'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '168', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '276000', 'serum_creatinine': '1.1', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '11', 'DEATH_EVENT': '1'}
# 15:{'age': '49', 'anaemia': '1', 'creatinine_phosphokinase': '80', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '427000', 'serum_creatinine': '1', 'serum_sodium': '138', 'sex': '0', 'smoking': '0', 'time': '12', 'DEATH_EVENT': '0'}
# 16:{'age': '82', 'anaemia': '1', 'creatinine_phosphokinase': '379', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '47000', 'serum_creatinine': '1.3', 'serum_sodium': '136', 'sex': '1', 'smoking': '0', 'time': '13', 'DEATH_EVENT': '1'}
# 17:{'age': '87', 'anaemia': '1', 'creatinine_phosphokinase': '149', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '262000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '14', 'DEATH_EVENT': '1'}
# 18:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '14', 'high_blood_pressure': '0', 'platelets': '166000', 'serum_creatinine': '0.8', 'serum_sodium': '127', 'sex': '1', 'smoking': '0', 'time': '14', 'DEATH_EVENT': '1'}
# 19:{'age': '70', 'anaemia': '1', 'creatinine_phosphokinase': '125', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '237000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '15', 'DEATH_EVENT': '1'}
# 20:{'age': '48', 'anaemia': '1', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '55', 'high_blood_pressure': '0', 'platelets': '87000', 'serum_creatinine': '1.9', 'serum_sodium': '121', 'sex': '0', 'smoking': '0', 'time': '15', 'DEATH_EVENT': '1'}
# 21:{'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '52', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '276000', 'serum_creatinine': '1.3', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '16', 'DEATH_EVENT': '0'}
# 22:{'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '128', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '297000', 'serum_creatinine': '1.6', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '20', 'DEATH_EVENT': '1'}
# 23:{'age': '68', 'anaemia': '1', 'creatinine_phosphokinase': '220', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '1', 'platelets': '289000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '20', 'DEATH_EVENT': '1'}
# 24:{'age': '53', 'anaemia': '0', 'creatinine_phosphokinase': '63', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '368000', 'serum_creatinine': '0.8', 'serum_sodium': '135', 'sex': '1', 'smoking': '0', 'time': '22', 'DEATH_EVENT': '0'}
# 25:{'age': '75', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '0', 'smoking': '0', 'time': '23', 'DEATH_EVENT': '1'}
# 26:{'age': '80', 'anaemia': '0', 'creatinine_phosphokinase': '148', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '149000', 'serum_creatinine': '1.9', 'serum_sodium': '144', 'sex': '1', 'smoking': '1', 'time': '23', 'DEATH_EVENT': '1'}
# 27:{'age': '95', 'anaemia': '1', 'creatinine_phosphokinase': '112', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '1', 'platelets': '196000', 'serum_creatinine': '1', 'serum_sodium': '138', 'sex': '0', 'smoking': '0', 'time': '24', 'DEATH_EVENT': '1'}
# 28:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '122', 'diabetes': '1', 'ejection_fraction': '45', 'high_blood_pressure': '1', 'platelets': '284000', 'serum_creatinine': '1.3', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '26', 'DEATH_EVENT': '1'}
# 29:{'age': '58', 'anaemia': '1', 'creatinine_phosphokinase': '60', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '153000', 'serum_creatinine': '5.8', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '26', 'DEATH_EVENT': '1'}
# 30:{'age': '82', 'anaemia': '0', 'creatinine_phosphokinase': '70', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '200000', 'serum_creatinine': '1.2', 'serum_sodium': '132', 'sex': '1', 'smoking': '1', 'time': '26', 'DEATH_EVENT': '1'}
# 31:{'age': '94', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '27', 'DEATH_EVENT': '1'}
# 32:{'age': '85', 'anaemia': '0', 'creatinine_phosphokinase': '23', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '0', 'platelets': '360000', 'serum_creatinine': '3', 'serum_sodium': '132', 'sex': '1', 'smoking': '0', 'time': '28', 'DEATH_EVENT': '1'}
# 33:{'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '249', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '1', 'platelets': '319000', 'serum_creatinine': '1', 'serum_sodium': '128', 'sex': '0', 'smoking': '0', 'time': '28', 'DEATH_EVENT': '1'}
# 34:{'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '159', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '302000', 'serum_creatinine': '1.2', 'serum_sodium': '138', 'sex': '0', 'smoking': '0', 'time': '29', 'DEATH_EVENT': '0'}
# 35:{'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '94', 'diabetes': '1', 'ejection_fraction': '50', 'high_blood_pressure': '1', 'platelets': '188000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '29', 'DEATH_EVENT': '1'}
# 36:{'age': '69', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '228000', 'serum_creatinine': '3.5', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '1'}
# 37:{'age': '90', 'anaemia': '1', 'creatinine_phosphokinase': '60', 'diabetes': '1', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '226000', 'serum_creatinine': '1', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '1'}
# 38:{'age': '82', 'anaemia': '1', 'creatinine_phosphokinase': '855', 'diabetes': '1', 'ejection_fraction': '50', 'high_blood_pressure': '1', 'platelets': '321000', 'serum_creatinine': '1', 'serum_sodium': '145', 'sex': '0', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '1'}
# 39:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '2656', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '305000', 'serum_creatinine': '2.3', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '0'}
# 40:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '235', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '329000', 'serum_creatinine': '3', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '1'}
# 41:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '1', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '1', 'smoking': '1', 'time': '31', 'DEATH_EVENT': '1'}
# 42:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '124', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '153000', 'serum_creatinine': '1.2', 'serum_sodium': '136', 'sex': '0', 'smoking': '1', 'time': '32', 'DEATH_EVENT': '1'}
# 43:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '571', 'diabetes': '1', 'ejection_fraction': '45', 'high_blood_pressure': '1', 'platelets': '185000', 'serum_creatinine': '1.2', 'serum_sodium': '139', 'sex': '1', 'smoking': '1', 'time': '33', 'DEATH_EVENT': '1'}
# 44:{'age': '72', 'anaemia': '0', 'creatinine_phosphokinase': '127', 'diabetes': '1', 'ejection_fraction': '50', 'high_blood_pressure': '1', 'platelets': '218000', 'serum_creatinine': '1', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '33', 'DEATH_EVENT': '0'}
# 45:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '588', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '194000', 'serum_creatinine': '1.1', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '33', 'DEATH_EVENT': '1'}
# 46:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '310000', 'serum_creatinine': '1.9', 'serum_sodium': '135', 'sex': '1', 'smoking': '1', 'time': '35', 'DEATH_EVENT': '1'}
# 47:{'age': '51', 'anaemia': '0', 'creatinine_phosphokinase': '1380', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '271000', 'serum_creatinine': '0.9', 'serum_sodium': '130', 'sex': '1', 'smoking': '0', 'time': '38', 'DEATH_EVENT': '1'}
# 48:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '451000', 'serum_creatinine': '0.6', 'serum_sodium': '138', 'sex': '1', 'smoking': '1', 'time': '40', 'DEATH_EVENT': '1'}
# 49:{'age': '80', 'anaemia': '1', 'creatinine_phosphokinase': '553', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '1', 'platelets': '140000', 'serum_creatinine': '4.4', 'serum_sodium': '133', 'sex': '1', 'smoking': '0', 'time': '41', 'DEATH_EVENT': '1'}
# 50:{'age': '57', 'anaemia': '1', 'creatinine_phosphokinase': '129', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '395000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '42', 'DEATH_EVENT': '1'}
# 51:{'age': '68', 'anaemia': '1', 'creatinine_phosphokinase': '577', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '166000', 'serum_creatinine': '1', 'serum_sodium': '138', 'sex': '1', 'smoking': '0', 'time': '43', 'DEATH_EVENT': '1'}
# 52:{'age': '53', 'anaemia': '1', 'creatinine_phosphokinase': '91', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '1', 'platelets': '418000', 'serum_creatinine': '1.4', 'serum_sodium': '139', 'sex': '0', 'smoking': '0', 'time': '43', 'DEATH_EVENT': '1'}
# 53:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '3964', 'diabetes': '1', 'ejection_fraction': '62', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '6.8', 'serum_sodium': '146', 'sex': '0', 'smoking': '0', 'time': '43', 'DEATH_EVENT': '1'}
# 54:{'age': '70', 'anaemia': '1', 'creatinine_phosphokinase': '69', 'diabetes': '1', 'ejection_fraction': '50', 'high_blood_pressure': '1', 'platelets': '351000', 'serum_creatinine': '1', 'serum_sodium': '134', 'sex': '0', 'smoking': '0', 'time': '44', 'DEATH_EVENT': '1'}
# 55:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '260', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '255000', 'serum_creatinine': '2.2', 'serum_sodium': '132', 'sex': '0', 'smoking': '1', 'time': '45', 'DEATH_EVENT': '1'}
# 56:{'age': '95', 'anaemia': '1', 'creatinine_phosphokinase': '371', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '461000', 'serum_creatinine': '2', 'serum_sodium': '132', 'sex': '1', 'smoking': '0', 'time': '50', 'DEATH_EVENT': '1'}
# 57:{'age': '70', 'anaemia': '1', 'creatinine_phosphokinase': '75', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '223000', 'serum_creatinine': '2.7', 'serum_sodium': '138', 'sex': '1', 'smoking': '1', 'time': '54', 'DEATH_EVENT': '0'}
# 58:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '607', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '216000', 'serum_creatinine': '0.6', 'serum_sodium': '138', 'sex': '1', 'smoking': '1', 'time': '54', 'DEATH_EVENT': '0'}
# 59:{'age': '49', 'anaemia': '0', 'creatinine_phosphokinase': '789', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '1', 'platelets': '319000', 'serum_creatinine': '1.1', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '55', 'DEATH_EVENT': '1'}
# 60:{'age': '72', 'anaemia': '0', 'creatinine_phosphokinase': '364', 'diabetes': '1', 'ejection_fraction': '20', 'high_blood_pressure': '1', 'platelets': '254000', 'serum_creatinine': '1.3', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '59', 'DEATH_EVENT': '1'}
# 61:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '7702', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '390000', 'serum_creatinine': '1', 'serum_sodium': '139', 'sex': '1', 'smoking': '0', 'time': '60', 'DEATH_EVENT': '1'}
# 62:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '318', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '1', 'platelets': '216000', 'serum_creatinine': '2.3', 'serum_sodium': '131', 'sex': '0', 'smoking': '0', 'time': '60', 'DEATH_EVENT': '1'}
# 63:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '109', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '254000', 'serum_creatinine': '1.1', 'serum_sodium': '139', 'sex': '1', 'smoking': '1', 'time': '60', 'DEATH_EVENT': '0'}
# 64:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '385000', 'serum_creatinine': '1', 'serum_sodium': '145', 'sex': '1', 'smoking': '0', 'time': '61', 'DEATH_EVENT': '1'}
# 65:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '80', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.18', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '63', 'DEATH_EVENT': '0'}
# 66:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '68', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '119000', 'serum_creatinine': '2.9', 'serum_sodium': '127', 'sex': '1', 'smoking': '1', 'time': '64', 'DEATH_EVENT': '1'}
# 67:{'age': '42', 'anaemia': '1', 'creatinine_phosphokinase': '250', 'diabetes': '1', 'ejection_fraction': '15', 'high_blood_pressure': '0', 'platelets': '213000', 'serum_creatinine': '1.3', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '65', 'DEATH_EVENT': '1'}
# 68:{'age': '72', 'anaemia': '1', 'creatinine_phosphokinase': '110', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '274000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '65', 'DEATH_EVENT': '1'}
# 69:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '161', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '244000', 'serum_creatinine': '1.2', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '66', 'DEATH_EVENT': '1'}
# 70:{'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '113', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '497000', 'serum_creatinine': '1.83', 'serum_sodium': '135', 'sex': '1', 'smoking': '0', 'time': '67', 'DEATH_EVENT': '1'}
# 71:{'age': '41', 'anaemia': '0', 'creatinine_phosphokinase': '148', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '374000', 'serum_creatinine': '0.8', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '68', 'DEATH_EVENT': '0'}
# 72:{'age': '58', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '122000', 'serum_creatinine': '0.9', 'serum_sodium': '139', 'sex': '1', 'smoking': '1', 'time': '71', 'DEATH_EVENT': '0'}
# 73:{'age': '85', 'anaemia': '0', 'creatinine_phosphokinase': '5882', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '243000', 'serum_creatinine': '1', 'serum_sodium': '132', 'sex': '1', 'smoking': '1', 'time': '72', 'DEATH_EVENT': '1'}
# 74:{'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '224', 'diabetes': '1', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '149000', 'serum_creatinine': '1.3', 'serum_sodium': '137', 'sex': '1', 'smoking': '1', 'time': '72', 'DEATH_EVENT': '0'}
# 75:{'age': '69', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '266000', 'serum_creatinine': '1.2', 'serum_sodium': '134', 'sex': '1', 'smoking': '1', 'time': '73', 'DEATH_EVENT': '1'}
# 76:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '47', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '204000', 'serum_creatinine': '0.7', 'serum_sodium': '139', 'sex': '1', 'smoking': '1', 'time': '73', 'DEATH_EVENT': '1'}
# 77:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '92', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '317000', 'serum_creatinine': '0.8', 'serum_sodium': '140', 'sex': '0', 'smoking': '1', 'time': '74', 'DEATH_EVENT': '0'}
# 78:{'age': '42', 'anaemia': '0', 'creatinine_phosphokinase': '102', 'diabetes': '1', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '237000', 'serum_creatinine': '1.2', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '74', 'DEATH_EVENT': '0'}
# 79:{'age': '75', 'anaemia': '1', 'creatinine_phosphokinase': '203', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '283000', 'serum_creatinine': '0.6', 'serum_sodium': '131', 'sex': '1', 'smoking': '1', 'time': '74', 'DEATH_EVENT': '0'}
# 80:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '336', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '1', 'platelets': '324000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '74', 'DEATH_EVENT': '0'}
# 81:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '69', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '293000', 'serum_creatinine': '1.7', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '75', 'DEATH_EVENT': '0'}
# 82:{'age': '67', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.18', 'serum_sodium': '137', 'sex': '1', 'smoking': '1', 'time': '76', 'DEATH_EVENT': '0'}
# 83:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '76', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '196000', 'serum_creatinine': '2.5', 'serum_sodium': '132', 'sex': '0', 'smoking': '0', 'time': '77', 'DEATH_EVENT': '1'}
# 84:{'age': '79', 'anaemia': '1', 'creatinine_phosphokinase': '55', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '1', 'platelets': '172000', 'serum_creatinine': '1.8', 'serum_sodium': '133', 'sex': '1', 'smoking': '0', 'time': '78', 'DEATH_EVENT': '0'}
# 85:{'age': '59', 'anaemia': '1', 'creatinine_phosphokinase': '280', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '302000', 'serum_creatinine': '1', 'serum_sodium': '141', 'sex': '0', 'smoking': '0', 'time': '78', 'DEATH_EVENT': '1'}
# 86:{'age': '51', 'anaemia': '0', 'creatinine_phosphokinase': '78', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '406000', 'serum_creatinine': '0.7', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '79', 'DEATH_EVENT': '0'}
# 87:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '47', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '1', 'platelets': '173000', 'serum_creatinine': '1.1', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '79', 'DEATH_EVENT': '0'}
# 88:{'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '68', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '304000', 'serum_creatinine': '0.8', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '79', 'DEATH_EVENT': '0'}
# 89:{'age': '44', 'anaemia': '0', 'creatinine_phosphokinase': '84', 'diabetes': '1', 'ejection_fraction': '40', 'high_blood_pressure': '1', 'platelets': '235000', 'serum_creatinine': '0.7', 'serum_sodium': '139', 'sex': '1', 'smoking': '0', 'time': '79', 'DEATH_EVENT': '0'}
# 90:{'age': '57', 'anaemia': '1', 'creatinine_phosphokinase': '115', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '181000', 'serum_creatinine': '1.1', 'serum_sodium': '144', 'sex': '1', 'smoking': '0', 'time': '79', 'DEATH_EVENT': '0'}
# 91:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '66', 'diabetes': '1', 'ejection_fraction': '45', 'high_blood_pressure': '0', 'platelets': '249000', 'serum_creatinine': '0.8', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '80', 'DEATH_EVENT': '0'}
# 92:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '897', 'diabetes': '1', 'ejection_fraction': '45', 'high_blood_pressure': '0', 'platelets': '297000', 'serum_creatinine': '1', 'serum_sodium': '133', 'sex': '1', 'smoking': '0', 'time': '80', 'DEATH_EVENT': '0'}
# 93:{'age': '42', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.18', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '82', 'DEATH_EVENT': '0'}
# 94:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '154', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '210000', 'serum_creatinine': '1.7', 'serum_sodium': '135', 'sex': '1', 'smoking': '0', 'time': '82', 'DEATH_EVENT': '1'}
# 95:{'age': '58', 'anaemia': '0', 'creatinine_phosphokinase': '144', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '327000', 'serum_creatinine': '0.7', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '83', 'DEATH_EVENT': '0'}
# 96:{'age': '58', 'anaemia': '1', 'creatinine_phosphokinase': '133', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '219000', 'serum_creatinine': '1', 'serum_sodium': '141', 'sex': '1', 'smoking': '0', 'time': '83', 'DEATH_EVENT': '0'}
# 97:{'age': '63', 'anaemia': '1', 'creatinine_phosphokinase': '514', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '254000', 'serum_creatinine': '1.3', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '83', 'DEATH_EVENT': '0'}
# 98:{'age': '70', 'anaemia': '1', 'creatinine_phosphokinase': '59', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '255000', 'serum_creatinine': '1.1', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '85', 'DEATH_EVENT': '0'}
# 99:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '156', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '318000', 'serum_creatinine': '1.2', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '85', 'DEATH_EVENT': '0'}
# 100:{'age': '63', 'anaemia': '1', 'creatinine_phosphokinase': '61', 'diabetes': '1', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '221000', 'serum_creatinine': '1.1', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '86', 'DEATH_EVENT': '0'}
# 101:{'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '305', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '298000', 'serum_creatinine': '1.1', 'serum_sodium': '141', 'sex': '1', 'smoking': '0', 'time': '87', 'DEATH_EVENT': '0'}
# 102:{'age': '75', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '1', 'platelets': '263358.03', 'serum_creatinine': '1.18', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '87', 'DEATH_EVENT': '0'}
# 103:{'age': '80', 'anaemia': '0', 'creatinine_phosphokinase': '898', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '149000', 'serum_creatinine': '1.1', 'serum_sodium': '144', 'sex': '1', 'smoking': '1', 'time': '87', 'DEATH_EVENT': '0'}
# 104:{'age': '42', 'anaemia': '0', 'creatinine_phosphokinase': '5209', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '226000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '87', 'DEATH_EVENT': '0'}
# 105:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '53', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '1', 'platelets': '286000', 'serum_creatinine': '2.3', 'serum_sodium': '143', 'sex': '0', 'smoking': '0', 'time': '87', 'DEATH_EVENT': '0'}
# 106:{'age': '72', 'anaemia': '1', 'creatinine_phosphokinase': '328', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '621000', 'serum_creatinine': '1.7', 'serum_sodium': '138', 'sex': '0', 'smoking': '1', 'time': '88', 'DEATH_EVENT': '1'}
# 107:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '748', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '0', 'platelets': '263000', 'serum_creatinine': '1.3', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '88', 'DEATH_EVENT': '0'}
# 108:{'age': '45', 'anaemia': '1', 'creatinine_phosphokinase': '1876', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '226000', 'serum_creatinine': '0.9', 'serum_sodium': '138', 'sex': '1', 'smoking': '0', 'time': '88', 'DEATH_EVENT': '0'}
# 109:{'age': '63', 'anaemia': '0', 'creatinine_phosphokinase': '936', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '304000', 'serum_creatinine': '1.1', 'serum_sodium': '133', 'sex': '1', 'smoking': '1', 'time': '88', 'DEATH_EVENT': '0'}
# 110:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '292', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '850000', 'serum_creatinine': '1.3', 'serum_sodium': '142', 'sex': '1', 'smoking': '1', 'time': '88', 'DEATH_EVENT': '0'}
# 111:{'age': '85', 'anaemia': '0', 'creatinine_phosphokinase': '129', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '306000', 'serum_creatinine': '1.2', 'serum_sodium': '132', 'sex': '1', 'smoking': '1', 'time': '90', 'DEATH_EVENT': '1'}
# 112:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '60', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '228000', 'serum_creatinine': '1.2', 'serum_sodium': '135', 'sex': '1', 'smoking': '1', 'time': '90', 'DEATH_EVENT': '0'}
# 113:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '369', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '252000', 'serum_creatinine': '1.6', 'serum_sodium': '136', 'sex': '1', 'smoking': '0', 'time': '90', 'DEATH_EVENT': '0'}
# 114:{'age': '70', 'anaemia': '1', 'creatinine_phosphokinase': '143', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '351000', 'serum_creatinine': '1.3', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '90', 'DEATH_EVENT': '1'}
# 115:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '754', 'diabetes': '1', 'ejection_fraction': '40', 'high_blood_pressure': '1', 'platelets': '328000', 'serum_creatinine': '1.2', 'serum_sodium': '126', 'sex': '1', 'smoking': '0', 'time': '91', 'DEATH_EVENT': '0'}
# 116:{'age': '58', 'anaemia': '1', 'creatinine_phosphokinase': '400', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '164000', 'serum_creatinine': '1', 'serum_sodium': '139', 'sex': '0', 'smoking': '0', 'time': '91', 'DEATH_EVENT': '0'}
# 117:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '96', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '271000', 'serum_creatinine': '0.7', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '94', 'DEATH_EVENT': '0'}
# 118:{'age': '85', 'anaemia': '1', 'creatinine_phosphokinase': '102', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '507000', 'serum_creatinine': '3.2', 'serum_sodium': '138', 'sex': '0', 'smoking': '0', 'time': '94', 'DEATH_EVENT': '0'}
# 119:{'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '113', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '203000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '94', 'DEATH_EVENT': '0'}
# 120:{'age': '86', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '0', 'smoking': '0', 'time': '95', 'DEATH_EVENT': '1'}
# 121:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '737', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '210000', 'serum_creatinine': '1.5', 'serum_sodium': '135', 'sex': '1', 'smoking': '1', 'time': '95', 'DEATH_EVENT': '0'}
# 122:{'age': '66', 'anaemia': '1', 'creatinine_phosphokinase': '68', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '162000', 'serum_creatinine': '1', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '95', 'DEATH_EVENT': '0'}
# 123:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '96', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '228000', 'serum_creatinine': '0.75', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '95', 'DEATH_EVENT': '0'}
# 124:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '127000', 'serum_creatinine': '0.9', 'serum_sodium': '145', 'sex': '0', 'smoking': '0', 'time': '95', 'DEATH_EVENT': '0'}
# 125:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '217000', 'serum_creatinine': '3.7', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '96', 'DEATH_EVENT': '1'}
# 126:{'age': '43', 'anaemia': '1', 'creatinine_phosphokinase': '358', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '237000', 'serum_creatinine': '1.3', 'serum_sodium': '135', 'sex': '0', 'smoking': '0', 'time': '97', 'DEATH_EVENT': '0'}
# 127:{'age': '46', 'anaemia': '0', 'creatinine_phosphokinase': '168', 'diabetes': '1', 'ejection_fraction': '17', 'high_blood_pressure': '1', 'platelets': '271000', 'serum_creatinine': '2.1', 'serum_sodium': '124', 'sex': '0', 'smoking': '0', 'time': '100', 'DEATH_EVENT': '1'}
# 128:{'age': '58', 'anaemia': '1', 'creatinine_phosphokinase': '200', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '300000', 'serum_creatinine': '0.8', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '104', 'DEATH_EVENT': '0'}
# 129:{'age': '61', 'anaemia': '0', 'creatinine_phosphokinase': '248', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '267000', 'serum_creatinine': '0.7', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '104', 'DEATH_EVENT': '0'}
# 130:{'age': '53', 'anaemia': '1', 'creatinine_phosphokinase': '270', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '227000', 'serum_creatinine': '3.4', 'serum_sodium': '145', 'sex': '1', 'smoking': '0', 'time': '105', 'DEATH_EVENT': '0'}
# 131:{'age': '53', 'anaemia': '1', 'creatinine_phosphokinase': '1808', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '249000', 'serum_creatinine': '0.7', 'serum_sodium': '138', 'sex': '1', 'smoking': '1', 'time': '106', 'DEATH_EVENT': '0'}
# 132:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '1082', 'diabetes': '1', 'ejection_fraction': '45', 'high_blood_pressure': '0', 'platelets': '250000', 'serum_creatinine': '6.1', 'serum_sodium': '131', 'sex': '1', 'smoking': '0', 'time': '107', 'DEATH_EVENT': '0'}
# 133:{'age': '46', 'anaemia': '0', 'creatinine_phosphokinase': '719', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '1', 'platelets': '263358.03', 'serum_creatinine': '1.18', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '107', 'DEATH_EVENT': '0'}
# 134:{'age': '63', 'anaemia': '0', 'creatinine_phosphokinase': '193', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '295000', 'serum_creatinine': '1.3', 'serum_sodium': '145', 'sex': '1', 'smoking': '1', 'time': '107', 'DEATH_EVENT': '0'}
# 135:{'age': '81', 'anaemia': '0', 'creatinine_phosphokinase': '4540', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '231000', 'serum_creatinine': '1.18', 'serum_sodium': '137', 'sex': '1', 'smoking': '1', 'time': '107', 'DEATH_EVENT': '0'}
# 136:{'age': '75', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.18', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '107', 'DEATH_EVENT': '0'}
# 137:{'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '59', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '172000', 'serum_creatinine': '0.9', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '107', 'DEATH_EVENT': '0'}
# 138:{'age': '68', 'anaemia': '1', 'creatinine_phosphokinase': '646', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '305000', 'serum_creatinine': '2.1', 'serum_sodium': '130', 'sex': '1', 'smoking': '0', 'time': '108', 'DEATH_EVENT': '0'}
# 139:{'age': '62', 'anaemia': '0', 'creatinine_phosphokinase': '281', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '221000', 'serum_creatinine': '1', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '108', 'DEATH_EVENT': '0'}
# 140:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '1548', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '211000', 'serum_creatinine': '0.8', 'serum_sodium': '138', 'sex': '1', 'smoking': '0', 'time': '108', 'DEATH_EVENT': '0'}
# 141:{'age': '80', 'anaemia': '0', 'creatinine_phosphokinase': '805', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.1', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '109', 'DEATH_EVENT': '1'}
# 142:{'age': '46', 'anaemia': '1', 'creatinine_phosphokinase': '291', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '348000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '109', 'DEATH_EVENT': '0'}
# 143:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '482', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '329000', 'serum_creatinine': '0.9', 'serum_sodium': '132', 'sex': '0', 'smoking': '0', 'time': '109', 'DEATH_EVENT': '0'}
# 144:{'age': '61', 'anaemia': '1', 'creatinine_phosphokinase': '84', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '1', 'platelets': '229000', 'serum_creatinine': '0.9', 'serum_sodium': '141', 'sex': '0', 'smoking': '0', 'time': '110', 'DEATH_EVENT': '0'}
# 145:{'age': '72', 'anaemia': '1', 'creatinine_phosphokinase': '943', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '1', 'platelets': '338000', 'serum_creatinine': '1.7', 'serum_sodium': '139', 'sex': '1', 'smoking': '1', 'time': '111', 'DEATH_EVENT': '1'}
# 146:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '185', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '266000', 'serum_creatinine': '0.7', 'serum_sodium': '141', 'sex': '1', 'smoking': '1', 'time': '112', 'DEATH_EVENT': '0'}
# 147:{'age': '52', 'anaemia': '0', 'creatinine_phosphokinase': '132', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '218000', 'serum_creatinine': '0.7', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '112', 'DEATH_EVENT': '0'}
# 148:{'age': '64', 'anaemia': '0', 'creatinine_phosphokinase': '1610', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '242000', 'serum_creatinine': '1', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '113', 'DEATH_EVENT': '0'}
# 149:{'age': '75', 'anaemia': '1', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '225000', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '113', 'DEATH_EVENT': '1'}
# 150:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '2261', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '1', 'platelets': '228000', 'serum_creatinine': '0.9', 'serum_sodium': '136', 'sex': '1', 'smoking': '0', 'time': '115', 'DEATH_EVENT': '0'}
# 151:{'age': '72', 'anaemia': '0', 'creatinine_phosphokinase': '233', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '1', 'platelets': '235000', 'serum_creatinine': '2.5', 'serum_sodium': '135', 'sex': '0', 'smoking': '0', 'time': '115', 'DEATH_EVENT': '1'}
# 152:{'age': '62', 'anaemia': '0', 'creatinine_phosphokinase': '30', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '244000', 'serum_creatinine': '0.9', 'serum_sodium': '139', 'sex': '1', 'smoking': '0', 'time': '117', 'DEATH_EVENT': '0'}
# 153:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '115', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '1', 'platelets': '184000', 'serum_creatinine': '0.9', 'serum_sodium': '134', 'sex': '1', 'smoking': '1', 'time': '118', 'DEATH_EVENT': '0'}
# 154:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '1846', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.18', 'serum_sodium': '137', 'sex': '1', 'smoking': '1', 'time': '119', 'DEATH_EVENT': '0'}
# 155:{'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '335', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '1', 'platelets': '235000', 'serum_creatinine': '0.8', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '120', 'DEATH_EVENT': '0'}
# 156:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '231', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '194000', 'serum_creatinine': '1.7', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '120', 'DEATH_EVENT': '0'}
# 157:{'age': '52', 'anaemia': '1', 'creatinine_phosphokinase': '58', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '277000', 'serum_creatinine': '1.4', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '120', 'DEATH_EVENT': '0'}
# 158:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '250', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '262000', 'serum_creatinine': '1', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '120', 'DEATH_EVENT': '0'}
# 159:{'age': '85', 'anaemia': '1', 'creatinine_phosphokinase': '910', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '235000', 'serum_creatinine': '1.3', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '121', 'DEATH_EVENT': '0'}
# 160:{'age': '59', 'anaemia': '1', 'creatinine_phosphokinase': '129', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '1', 'platelets': '362000', 'serum_creatinine': '1.1', 'serum_sodium': '139', 'sex': '1', 'smoking': '1', 'time': '121', 'DEATH_EVENT': '0'}
# 161:{'age': '66', 'anaemia': '1', 'creatinine_phosphokinase': '72', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '1', 'platelets': '242000', 'serum_creatinine': '1.2', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '121', 'DEATH_EVENT': '0'}
# 162:{'age': '45', 'anaemia': '1', 'creatinine_phosphokinase': '130', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '174000', 'serum_creatinine': '0.8', 'serum_sodium': '139', 'sex': '1', 'smoking': '1', 'time': '121', 'DEATH_EVENT': '0'}
# 163:{'age': '63', 'anaemia': '1', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '448000', 'serum_creatinine': '0.9', 'serum_sodium': '137', 'sex': '1', 'smoking': '1', 'time': '123', 'DEATH_EVENT': '0'}
# 164:{'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '2334', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '75000', 'serum_creatinine': '0.9', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '126', 'DEATH_EVENT': '1'}
# 165:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '2442', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '334000', 'serum_creatinine': '1.1', 'serum_sodium': '139', 'sex': '1', 'smoking': '0', 'time': '129', 'DEATH_EVENT': '1'}
# 166:{'age': '80', 'anaemia': '0', 'creatinine_phosphokinase': '776', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '192000', 'serum_creatinine': '1.3', 'serum_sodium': '135', 'sex': '0', 'smoking': '0', 'time': '130', 'DEATH_EVENT': '1'}
# 167:{'age': '53', 'anaemia': '0', 'creatinine_phosphokinase': '196', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '220000', 'serum_creatinine': '0.7', 'serum_sodium': '133', 'sex': '1', 'smoking': '1', 'time': '134', 'DEATH_EVENT': '0'}
# 168:{'age': '59', 'anaemia': '0', 'creatinine_phosphokinase': '66', 'diabetes': '1', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '70000', 'serum_creatinine': '2.4', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '135', 'DEATH_EVENT': '1'}
# 169:{'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '270000', 'serum_creatinine': '1', 'serum_sodium': '138', 'sex': '0', 'smoking': '0', 'time': '140', 'DEATH_EVENT': '0'}
# 170:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '835', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '1', 'platelets': '305000', 'serum_creatinine': '0.8', 'serum_sodium': '133', 'sex': '0', 'smoking': '0', 'time': '145', 'DEATH_EVENT': '0'}
# 171:{'age': '51', 'anaemia': '1', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.5', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '145', 'DEATH_EVENT': '0'}
# 172:{'age': '52', 'anaemia': '0', 'creatinine_phosphokinase': '3966', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '325000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '146', 'DEATH_EVENT': '0'}
# 173:{'age': '70', 'anaemia': '1', 'creatinine_phosphokinase': '171', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '176000', 'serum_creatinine': '1.1', 'serum_sodium': '145', 'sex': '1', 'smoking': '1', 'time': '146', 'DEATH_EVENT': '0'}
# 174:{'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '115', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '189000', 'serum_creatinine': '0.8', 'serum_sodium': '139', 'sex': '1', 'smoking': '0', 'time': '146', 'DEATH_EVENT': '0'}
# ...
# 243:{'age': '40', 'anaemia': '0', 'creatinine_phosphokinase': '90', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '255000', 'serum_creatinine': '1.1', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '212', 'DEATH_EVENT': '0'}
# 244:{'age': '73', 'anaemia': '1', 'creatinine_phosphokinase': '1185', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '1', 'platelets': '220000', 'serum_creatinine': '0.9', 'serum_sodium': '141', 'sex': '0', 'smoking': '0', 'time': '213', 'DEATH_EVENT': '0'}
# 245:{'age': '54', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '264000', 'serum_creatinine': '1.8', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '213', 'DEATH_EVENT': '0'}
# 246:{'age': '61', 'anaemia': '1', 'creatinine_phosphokinase': '80', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '282000', 'serum_creatinine': '1.4', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '213', 'DEATH_EVENT': '0'}
# 247:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '2017', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '314000', 'serum_creatinine': '1.1', 'serum_sodium': '138', 'sex': '1', 'smoking': '0', 'time': '214', 'DEATH_EVENT': '1'}
# 248:{'age': '64', 'anaemia': '0', 'creatinine_phosphokinase': '143', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '246000', 'serum_creatinine': '2.4', 'serum_sodium': '135', 'sex': '1', 'smoking': '0', 'time': '214', 'DEATH_EVENT': '0'}
# 249:{'age': '40', 'anaemia': '0', 'creatinine_phosphokinase': '624', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '301000', 'serum_creatinine': '1', 'serum_sodium': '142', 'sex': '1', 'smoking': '1', 'time': '214', 'DEATH_EVENT': '0'}
# 250:{'age': '53', 'anaemia': '0', 'creatinine_phosphokinase': '207', 'diabetes': '1', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '223000', 'serum_creatinine': '1.2', 'serum_sodium': '130', 'sex': '0', 'smoking': '0', 'time': '214', 'DEATH_EVENT': '0'}
# 251:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '2522', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '404000', 'serum_creatinine': '0.5', 'serum_sodium': '139', 'sex': '0', 'smoking': '0', 'time': '214', 'DEATH_EVENT': '0'}
# 252:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '572', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '231000', 'serum_creatinine': '0.8', 'serum_sodium': '143', 'sex': '0', 'smoking': '0', 'time': '215', 'DEATH_EVENT': '0'}
# 253:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '245', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '1', 'platelets': '274000', 'serum_creatinine': '1', 'serum_sodium': '133', 'sex': '1', 'smoking': '0', 'time': '215', 'DEATH_EVENT': '0'}
# 254:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '88', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '1', 'platelets': '236000', 'serum_creatinine': '1.2', 'serum_sodium': '132', 'sex': '0', 'smoking': '0', 'time': '215', 'DEATH_EVENT': '0'}
# 255:{'age': '53', 'anaemia': '1', 'creatinine_phosphokinase': '446', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '1', 'platelets': '263358.03', 'serum_creatinine': '1', 'serum_sodium': '139', 'sex': '1', 'smoking': '0', 'time': '215', 'DEATH_EVENT': '0'}
# 256:{'age': '52', 'anaemia': '1', 'creatinine_phosphokinase': '191', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '334000', 'serum_creatinine': '1', 'serum_sodium': '142', 'sex': '1', 'smoking': '1', 'time': '216', 'DEATH_EVENT': '0'}
# 257:{'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '326', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '294000', 'serum_creatinine': '1.7', 'serum_sodium': '139', 'sex': '0', 'smoking': '0', 'time': '220', 'DEATH_EVENT': '0'}
# 258:{'age': '58', 'anaemia': '0', 'creatinine_phosphokinase': '132', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '253000', 'serum_creatinine': '1', 'serum_sodium': '139', 'sex': '1', 'smoking': '0', 'time': '230', 'DEATH_EVENT': '0'}
# 259:{'age': '45', 'anaemia': '1', 'creatinine_phosphokinase': '66', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '233000', 'serum_creatinine': '0.8', 'serum_sodium': '135', 'sex': '1', 'smoking': '0', 'time': '230', 'DEATH_EVENT': '0'}
# 260:{'age': '53', 'anaemia': '0', 'creatinine_phosphokinase': '56', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '308000', 'serum_creatinine': '0.7', 'serum_sodium': '135', 'sex': '1', 'smoking': '1', 'time': '231', 'DEATH_EVENT': '0'}
# 261:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '66', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '203000', 'serum_creatinine': '1', 'serum_sodium': '138', 'sex': '1', 'smoking': '0', 'time': '233', 'DEATH_EVENT': '0'}
# 262:{'age': '62', 'anaemia': '1', 'creatinine_phosphokinase': '655', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '283000', 'serum_creatinine': '0.7', 'serum_sodium': '133', 'sex': '0', 'smoking': '0', 'time': '233', 'DEATH_EVENT': '0'}
# 263:{'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '258', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '198000', 'serum_creatinine': '1.4', 'serum_sodium': '129', 'sex': '1', 'smoking': '0', 'time': '235', 'DEATH_EVENT': '1'}
# 264:{'age': '68', 'anaemia': '1', 'creatinine_phosphokinase': '157', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '208000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '237', 'DEATH_EVENT': '0'}
# 265:{'age': '61', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '147000', 'serum_creatinine': '1.2', 'serum_sodium': '141', 'sex': '1', 'smoking': '0', 'time': '237', 'DEATH_EVENT': '0'}
# 266:{'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '298', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '362000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '240', 'DEATH_EVENT': '0'}
# 267:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '1199', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '1', 'smoking': '1', 'time': '241', 'DEATH_EVENT': '1'}
# 268:{'age': '56', 'anaemia': '1', 'creatinine_phosphokinase': '135', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '133000', 'serum_creatinine': '1.7', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '244', 'DEATH_EVENT': '0'}
# 269:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '302000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '244', 'DEATH_EVENT': '0'}
# 270:{'age': '40', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '222000', 'serum_creatinine': '1', 'serum_sodium': '132', 'sex': '1', 'smoking': '0', 'time': '244', 'DEATH_EVENT': '0'}
# 271:{'age': '44', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '1', 'platelets': '263358.03', 'serum_creatinine': '1.6', 'serum_sodium': '130', 'sex': '1', 'smoking': '1', 'time': '244', 'DEATH_EVENT': '0'}
# 272:{'age': '51', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '221000', 'serum_creatinine': '0.9', 'serum_sodium': '134', 'sex': '0', 'smoking': '0', 'time': '244', 'DEATH_EVENT': '0'}
# 273:{'age': '67', 'anaemia': '0', 'creatinine_phosphokinase': '213', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '215000', 'serum_creatinine': '1.2', 'serum_sodium': '133', 'sex': '0', 'smoking': '0', 'time': '245', 'DEATH_EVENT': '0'}
# 274:{'age': '42', 'anaemia': '0', 'creatinine_phosphokinase': '64', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '189000', 'serum_creatinine': '0.7', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '245', 'DEATH_EVENT': '0'}
# 275:{'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '257', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '150000', 'serum_creatinine': '1', 'serum_sodium': '137', 'sex': '1', 'smoking': '1', 'time': '245', 'DEATH_EVENT': '0'}
# 276:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '422000', 'serum_creatinine': '0.8', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '245', 'DEATH_EVENT': '0'}
# 277:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '618', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '327000', 'serum_creatinine': '1.1', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '245', 'DEATH_EVENT': '0'}
# 278:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '25100', 'serum_creatinine': '1.1', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '246', 'DEATH_EVENT': '0'}
# 279:{'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '1051', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '232000', 'serum_creatinine': '0.7', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '246', 'DEATH_EVENT': '0'}
# 280:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '84', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '451000', 'serum_creatinine': '1.3', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '246', 'DEATH_EVENT': '0'}
# 281:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '2695', 'diabetes': '1', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '241000', 'serum_creatinine': '1', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '247', 'DEATH_EVENT': '0'}
# 282:{'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '51000', 'serum_creatinine': '2.7', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '250', 'DEATH_EVENT': '0'}
# 283:{'age': '42', 'anaemia': '0', 'creatinine_phosphokinase': '64', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '215000', 'serum_creatinine': '3.8', 'serum_sodium': '128', 'sex': '1', 'smoking': '1', 'time': '250', 'DEATH_EVENT': '0'}
# 284:{'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '1688', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.1', 'serum_sodium': '138', 'sex': '1', 'smoking': '1', 'time': '250', 'DEATH_EVENT': '0'}
# 285:{'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '54', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '279000', 'serum_creatinine': '0.8', 'serum_sodium': '141', 'sex': '1', 'smoking': '0', 'time': '250', 'DEATH_EVENT': '0'}
# 286:{'age': '55', 'anaemia': '1', 'creatinine_phosphokinase': '170', 'diabetes': '1', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '336000', 'serum_creatinine': '1.2', 'serum_sodium': '135', 'sex': '1', 'smoking': '0', 'time': '250', 'DEATH_EVENT': '0'}
# 287:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '253', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '279000', 'serum_creatinine': '1.7', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '250', 'DEATH_EVENT': '0'}
# 288:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '55', 'high_blood_pressure': '0', 'platelets': '543000', 'serum_creatinine': '1', 'serum_sodium': '132', 'sex': '0', 'smoking': '0', 'time': '250', 'DEATH_EVENT': '0'}
# 289:{'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '892', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.1', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '256', 'DEATH_EVENT': '0'}
# 290:{'age': '90', 'anaemia': '1', 'creatinine_phosphokinase': '337', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '390000', 'serum_creatinine': '0.9', 'serum_sodium': '144', 'sex': '0', 'smoking': '0', 'time': '256', 'DEATH_EVENT': '0'}
# 291:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '615', 'diabetes': '1', 'ejection_fraction': '55', 'high_blood_pressure': '0', 'platelets': '222000', 'serum_creatinine': '0.8', 'serum_sodium': '141', 'sex': '0', 'smoking': '0', 'time': '257', 'DEATH_EVENT': '0'}
# 292:{'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '320', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '133000', 'serum_creatinine': '1.4', 'serum_sodium': '139', 'sex': '1', 'smoking': '0', 'time': '258', 'DEATH_EVENT': '0'}
# 293:{'age': '52', 'anaemia': '0', 'creatinine_phosphokinase': '190', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '382000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '258', 'DEATH_EVENT': '0'}
# 294:{'age': '63', 'anaemia': '1', 'creatinine_phosphokinase': '103', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '179000', 'serum_creatinine': '0.9', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '270', 'DEATH_EVENT': '0'}
# 295:{'age': '62', 'anaemia': '0', 'creatinine_phosphokinase': '61', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '1', 'platelets': '155000', 'serum_creatinine': '1.1', 'serum_sodium': '143', 'sex': '1', 'smoking': '1', 'time': '270', 'DEATH_EVENT': '0'}
# 296:{'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '1820', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '270000', 'serum_creatinine': '1.2', 'serum_sodium': '139', 'sex': '0', 'smoking': '0', 'time': '271', 'DEATH_EVENT': '0'}
# 297:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '2060', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '742000', 'serum_creatinine': '0.8', 'serum_sodium': '138', 'sex': '0', 'smoking': '0', 'time': '278', 'DEATH_EVENT': '0'}
# 298:{'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '2413', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '140000', 'serum_creatinine': '1.4', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '280', 'DEATH_EVENT': '0'}
# 299:{'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '196', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '0', 'platelets': '395000', 'serum_creatinine': '1.6', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '285', 'DEATH_EVENT': '0'}

# %%
 #1. Function for computing the average age, modal age, and median age of those whose heart failure resulted in death
import csv
from collections import Counter
def death_age_statistics(csv_data):
    sum_of_ages = 0
    count = 0
    ages = []

    for patient_id, details in csv_data.items():
        age = float(details["age"])
        DEATH_EVENT = int(details["DEATH_EVENT"])
        if DEATH_EVENT == 1:  # Filter for those who died
            sum_of_ages += age
            count += 1
            ages.append(age)

    if count > 0:
        average_age = sum_of_ages / count
    else:
        average_age = 0

    # Calculate modal age
    age_frequency = Counter(ages)
    modal_age = age_frequency.most_common(1)[0][0] if age_frequency else None

    # Calculate median age
    ages.sort()
    y = len(ages)
    if y % 2 == 1:
        median_age = ages[y // 2]
    else:
        median_age = (ages[y // 2 - 1] + ages[y // 2]) / 2 if y > 0 else 0

    # Print the results
    print(f"Information on those who died due to heart failure:")
    print(f" Average Age: {average_age}")
    print(f"Modal Age: {modal_age}")
    print(f"Median Age: {median_age}")

death_age_statistics(csv_data)
# Out:
# Information on those who died due to heart failure:
#  Average Age: 65.21528125
# Modal Age: 60.0
# Median Age: 65.0

# %%
# 2. Function for computing the average time taken for those whose heart failure did not result in death
def non_death_time_statistics(csv_data):
    total_time_taken = 0
    count = 0
    for patient_id, details in csv_data.items():
        time = int(details['time'])
        DEATH_EVENT = int(details["DEATH_EVENT"])
        if DEATH_EVENT == 0:  # Filter for those who survived
            total_time_taken += time
            count += 1

    if count > 0:
        average_time = total_time_taken / count
    else:
        average_time = 0

    # Print the result
    print(f"Average time for those whose heart failure did not result in death is {average_time}")

non_death_time_statistics(csv_data)
# Out:
# Average time for those whose heart failure did not result in death is 158.3399014778325

# %%
# 3. Function to compute median age, average age, and modal age of those with high blood pressure
def high_bp_statistics(csv_data):
    sum_of_ages = 0
    count = 0
    ages = []

    for patient_id, details in csv_data.items():
        age = float(details["age"])
        high_bp = int(details["high_blood_pressure"])
        if high_bp == 1:  # Filter for high blood pressure cases
            sum_of_ages += age
            count += 1
            ages.append(age)

    if count > 0:
        average_age = sum_of_ages / count
    else:
        average_age = 0

    # Calculate modal age
    age_frequency = Counter(ages)
    modal_age = age_frequency.most_common(1)[0][0] if age_frequency else None

    # Calculate median age
    ages.sort()
    y = len(ages)
    if y % 2 == 1:
        median_age = ages[y // 2]
    else:
        median_age = (ages[y // 2 - 1] + ages[y // 2]) / 2 if y > 0 else 0

    # Print the results
    print(f"Information on those who have high blood pressure:")
    print(f"Their average Age is {average_age}")
    print(f"Their modal Age is {modal_age}")
    print(f"Their Median Age is {median_age}")

high_bp_statistics(csv_data)
# Out:
# Information on those who have high blood pressure:
# Their average Age is 62.339685714285714
# Their modal Age is 70.0
# Their Median Age is 62.0

# %%
# 4. Function to compute median age, average age, and modal age of those with diabetes
def diabetes_statistics(csv_data):
    sum_of_ages = 0
    count = 0
    ages = []

    for patient_id, details in csv_data.items():
        age = float(details["age"])
        diabetes_status = int(details["diabetes"])
        if diabetes_status == 1:  # Filter for diabetes cases
            sum_of_ages += age
            count += 1
            ages.append(age)

    if count > 0:
        average_age = sum_of_ages / count
    else:
        average_age = 0

    # Calculate modal age
    age_frequency = Counter(ages)
    modal_age = age_frequency.most_common(1)[0][0] if age_frequency else None

    # Calculate median age
    ages.sort()
    y = len(ages)
    if y % 2 == 1:
        median_age = ages[y // 2]
    else:
        median_age = (ages[y // 2 - 1] + ages[y // 2]) / 2 if y > 0 else 0

    # Print the results
    print(f"Information of Diabetic patients")
    print(f"Their Average Ageis {average_age}")
    print(f"Their Modal Age is  {modal_age}")
    print(f"Their Median Age is {median_age}")

diabetes_statistics(csv_data)
# Out:
# Information of Diabetic patients
# Their Average Ageis 59.41867200000001
# Their Modal Age is  60.0
# Their Median Age is 60.0

# %%
# 5. Function to determine whether diabetes is linked to smoking and high blood pressure
def diabetes_smoking_highbp_link(csv_data):
    diabetes_smoking_highbp_count = 0
    diabetes_smoking_no_highbp_count = 0
    diabetes_no_smoking_highbp_count = 0
    diabetes_no_smoking_no_highbp_count = 0

    # Count occurrences
    for patient_id, details in csv_data.items():
        diabetes = int(details['diabetes'])
        smoking = int(details['smoking'])
        high_blood_pressure = int(details['high_blood_pressure'])

        if diabetes == 1 and smoking == 1 and high_blood_pressure == 1:
            diabetes_smoking_highbp_count += 1
        elif diabetes == 1 and smoking == 1 and high_blood_pressure == 0:
            diabetes_smoking_no_highbp_count += 1
        elif diabetes == 1 and smoking == 0 and high_blood_pressure == 1:
            diabetes_no_smoking_highbp_count += 1
        elif diabetes == 1 and smoking == 0 and high_blood_pressure == 0:
            diabetes_no_smoking_no_highbp_count += 1

    # Print the contingency table
    print(f"Link between diabetes, smoking, and high blood pressure:")
    print(f"Diabetes, Smoking, and High BP: {diabetes_smoking_highbp_count}")
    print(f"Diabetes, Smoking, No High BP: {diabetes_smoking_no_highbp_count}")
    print(f"Diabetes, No Smoking, High BP: {diabetes_no_smoking_highbp_count}")
    print(f"Diabetes, No Smoking, No High BP: {diabetes_no_smoking_no_highbp_count}")
    print(f"There is no significant relationship between diabetes,smoking and high blood pressure")
diabetes_smoking_highbp_link(csv_data)

# %%
# 6. Function to compute the average serum sodium of those with diabetes
def average_serum_sodium_diabetes(csv_data):
    total_sodium = 0
    count = 0
    for patient_id, details in csv_data.items():
        serum_sodium = float(details["serum_sodium"])
        diabetes_status = int(details["diabetes"])
        if diabetes_status == 1:  # Filter for diabetes cases
            total_sodium += serum_sodium
            count += 1

    if count > 0:
        average_sodium = total_sodium / count
    else:
        average_sodium = 0

    # Print the result
    print(f"Average Serum Sodium for those with diabetes: {average_sodium}")

average_serum_sodium_diabetes(csv_data)

# %%
# 7. Function to determine if anaemia is linked to smoking
def anaemia_smoking_link(csv_data):
    anaemia_smoking_count = 0
    anaemia_non_smoking_count = 0
    for patient_id, details in csv_data.items():
        anaemia = int(details["anaemia"])
        smoking = int(details["smoking"])

        if anaemia == 1 and smoking == 1:
            anaemia_smoking_count += 1
        elif anaemia == 1 and smoking == 0:
            anaemia_non_smoking_count += 1

    print(f"Link between anaemia and smoking:")
    print(f"Anaemia with smoking: {anaemia_smoking_count}")
    print(f"Anaemia without smoking: {anaemia_non_smoking_count}")
    print(f"This suggests anaemia is not linked to smoking")

anaemia_smoking_link(csv_data)
# Out:
# Link between anaemia and smoking:
# Anaemia with smoking: 34
# Anaemia without smoking: 95
# This suggests anaemia is not linked to smoking

# %%
# 8. Function that returns anyone without high blood pressure that died of heart failure
def no_highbp_death(csv_data):
    for patient_id, details in csv_data.items():
        DEATH_EVENT = int(details["DEATH_EVENT"])
        high_blood_pressure = int(details["high_blood_pressure"])

        if DEATH_EVENT == 1 and high_blood_pressure == 0:
            print(details)

no_highbp_death(csv_data)
# Out:
# {'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '7861', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.1', 'serum_sodium': '136', 'sex': '1', 'smoking': '0', 'time': '6', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '146', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '162000', 'serum_creatinine': '1.3', 'serum_sodium': '129', 'sex': '1', 'smoking': '1', 'time': '7', 'DEATH_EVENT': '1'}
# {'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '111', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '210000', 'serum_creatinine': '1.9', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '7', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '160', 'diabetes': '1', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '327000', 'serum_creatinine': '2.7', 'serum_sodium': '116', 'sex': '0', 'smoking': '0', 'time': '8', 'DEATH_EVENT': '1'}
# {'age': '75', 'anaemia': '1', 'creatinine_phosphokinase': '246', 'diabetes': '0', 'ejection_fraction': '15', 'high_blood_pressure': '0', 'platelets': '127000', 'serum_creatinine': '1.2', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '10', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '315', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '454000', 'serum_creatinine': '1.1', 'serum_sodium': '131', 'sex': '1', 'smoking': '1', 'time': '10', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '157', 'diabetes': '0', 'ejection_fraction': '65', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.5', 'serum_sodium': '138', 'sex': '0', 'smoking': '0', 'time': '10', 'DEATH_EVENT': '1'}
# {'age': '45', 'anaemia': '1', 'creatinine_phosphokinase': '981', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '136000', 'serum_creatinine': '1.1', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '11', 'DEATH_EVENT': '1'}
# {'age': '82', 'anaemia': '1', 'creatinine_phosphokinase': '379', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '47000', 'serum_creatinine': '1.3', 'serum_sodium': '136', 'sex': '1', 'smoking': '0', 'time': '13', 'DEATH_EVENT': '1'}
# {'age': '87', 'anaemia': '1', 'creatinine_phosphokinase': '149', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '262000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '14', 'DEATH_EVENT': '1'}
# {'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '14', 'high_blood_pressure': '0', 'platelets': '166000', 'serum_creatinine': '0.8', 'serum_sodium': '127', 'sex': '1', 'smoking': '0', 'time': '14', 'DEATH_EVENT': '1'}
# {'age': '48', 'anaemia': '1', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '55', 'high_blood_pressure': '0', 'platelets': '87000', 'serum_creatinine': '1.9', 'serum_sodium': '121', 'sex': '0', 'smoking': '0', 'time': '15', 'DEATH_EVENT': '1'}
# {'age': '80', 'anaemia': '0', 'creatinine_phosphokinase': '148', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '149000', 'serum_creatinine': '1.9', 'serum_sodium': '144', 'sex': '1', 'smoking': '1', 'time': '23', 'DEATH_EVENT': '1'}
# {'age': '58', 'anaemia': '1', 'creatinine_phosphokinase': '60', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '153000', 'serum_creatinine': '5.8', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '26', 'DEATH_EVENT': '1'}
# {'age': '82', 'anaemia': '0', 'creatinine_phosphokinase': '70', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '200000', 'serum_creatinine': '1.2', 'serum_sodium': '132', 'sex': '1', 'smoking': '1', 'time': '26', 'DEATH_EVENT': '1'}
# {'age': '85', 'anaemia': '0', 'creatinine_phosphokinase': '23', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '0', 'platelets': '360000', 'serum_creatinine': '3', 'serum_sodium': '132', 'sex': '1', 'smoking': '0', 'time': '28', 'DEATH_EVENT': '1'}
# {'age': '69', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '228000', 'serum_creatinine': '3.5', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '1'}
# {'age': '90', 'anaemia': '1', 'creatinine_phosphokinase': '60', 'diabetes': '1', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '226000', 'serum_creatinine': '1', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '235', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '329000', 'serum_creatinine': '3', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '588', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '194000', 'serum_creatinine': '1.1', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '33', 'DEATH_EVENT': '1'}
# {'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '310000', 'serum_creatinine': '1.9', 'serum_sodium': '135', 'sex': '1', 'smoking': '1', 'time': '35', 'DEATH_EVENT': '1'}
# {'age': '57', 'anaemia': '1', 'creatinine_phosphokinase': '129', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '395000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '42', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '3964', 'diabetes': '1', 'ejection_fraction': '62', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '6.8', 'serum_sodium': '146', 'sex': '0', 'smoking': '0', 'time': '43', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '260', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '255000', 'serum_creatinine': '2.2', 'serum_sodium': '132', 'sex': '0', 'smoking': '1', 'time': '45', 'DEATH_EVENT': '1'}
# {'age': '95', 'anaemia': '1', 'creatinine_phosphokinase': '371', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '461000', 'serum_creatinine': '2', 'serum_sodium': '132', 'sex': '1', 'smoking': '0', 'time': '50', 'DEATH_EVENT': '1'}
# {'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '385000', 'serum_creatinine': '1', 'serum_sodium': '145', 'sex': '1', 'smoking': '0', 'time': '61', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '68', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '119000', 'serum_creatinine': '2.9', 'serum_sodium': '127', 'sex': '1', 'smoking': '1', 'time': '64', 'DEATH_EVENT': '1'}
# {'age': '42', 'anaemia': '1', 'creatinine_phosphokinase': '250', 'diabetes': '1', 'ejection_fraction': '15', 'high_blood_pressure': '0', 'platelets': '213000', 'serum_creatinine': '1.3', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '65', 'DEATH_EVENT': '1'}
# {'age': '72', 'anaemia': '1', 'creatinine_phosphokinase': '110', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '274000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '65', 'DEATH_EVENT': '1'}
# {'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '161', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '244000', 'serum_creatinine': '1.2', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '66', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '113', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '497000', 'serum_creatinine': '1.83', 'serum_sodium': '135', 'sex': '1', 'smoking': '0', 'time': '67', 'DEATH_EVENT': '1'}
# {'age': '85', 'anaemia': '0', 'creatinine_phosphokinase': '5882', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '243000', 'serum_creatinine': '1', 'serum_sodium': '132', 'sex': '1', 'smoking': '1', 'time': '72', 'DEATH_EVENT': '1'}
# {'age': '69', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '266000', 'serum_creatinine': '1.2', 'serum_sodium': '134', 'sex': '1', 'smoking': '1', 'time': '73', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '47', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '204000', 'serum_creatinine': '0.7', 'serum_sodium': '139', 'sex': '1', 'smoking': '1', 'time': '73', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '76', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '196000', 'serum_creatinine': '2.5', 'serum_sodium': '132', 'sex': '0', 'smoking': '0', 'time': '77', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '154', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '210000', 'serum_creatinine': '1.7', 'serum_sodium': '135', 'sex': '1', 'smoking': '0', 'time': '82', 'DEATH_EVENT': '1'}
# {'age': '85', 'anaemia': '0', 'creatinine_phosphokinase': '129', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '306000', 'serum_creatinine': '1.2', 'serum_sodium': '132', 'sex': '1', 'smoking': '1', 'time': '90', 'DEATH_EVENT': '1'}
# {'age': '70', 'anaemia': '1', 'creatinine_phosphokinase': '143', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '351000', 'serum_creatinine': '1.3', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '90', 'DEATH_EVENT': '1'}
# {'age': '86', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '0', 'smoking': '0', 'time': '95', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '217000', 'serum_creatinine': '3.7', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '96', 'DEATH_EVENT': '1'}
# {'age': '80', 'anaemia': '0', 'creatinine_phosphokinase': '805', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.1', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '109', 'DEATH_EVENT': '1'}
# {'age': '75', 'anaemia': '1', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '225000', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '113', 'DEATH_EVENT': '1'}
# {'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '2334', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '75000', 'serum_creatinine': '0.9', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '126', 'DEATH_EVENT': '1'}
# {'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '2442', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '334000', 'serum_creatinine': '1.1', 'serum_sodium': '139', 'sex': '1', 'smoking': '0', 'time': '129', 'DEATH_EVENT': '1'}
# {'age': '59', 'anaemia': '0', 'creatinine_phosphokinase': '66', 'diabetes': '1', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '70000', 'serum_creatinine': '2.4', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '135', 'DEATH_EVENT': '1'}
# {'age': '59', 'anaemia': '1', 'creatinine_phosphokinase': '176', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '221000', 'serum_creatinine': '1', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '150', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '395', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '265000', 'serum_creatinine': '1.2', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '154', 'DEATH_EVENT': '1'}
# {'age': '58', 'anaemia': '1', 'creatinine_phosphokinase': '145', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '219000', 'serum_creatinine': '1.2', 'serum_sodium': '137', 'sex': '1', 'smoking': '1', 'time': '170', 'DEATH_EVENT': '1'}
# {'age': '60.667', 'anaemia': '1', 'creatinine_phosphokinase': '104', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '389000', 'serum_creatinine': '1.5', 'serum_sodium': '136', 'sex': '1', 'smoking': '0', 'time': '171', 'DEATH_EVENT': '1'}
# {'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '153000', 'serum_creatinine': '0.6', 'serum_sodium': '134', 'sex': '0', 'smoking': '0', 'time': '172', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '1896', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '365000', 'serum_creatinine': '2.1', 'serum_sodium': '144', 'sex': '0', 'smoking': '0', 'time': '172', 'DEATH_EVENT': '1'}
# {'age': '77', 'anaemia': '1', 'creatinine_phosphokinase': '418', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '0', 'platelets': '223000', 'serum_creatinine': '1.8', 'serum_sodium': '145', 'sex': '1', 'smoking': '0', 'time': '180', 'DEATH_EVENT': '1'}
# {'age': '73', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '198', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '166', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '62000', 'serum_creatinine': '1.7', 'serum_sodium': '127', 'sex': '0', 'smoking': '0', 'time': '207', 'DEATH_EVENT': '1'}
# {'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '2017', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '314000', 'serum_creatinine': '1.1', 'serum_sodium': '138', 'sex': '1', 'smoking': '0', 'time': '214', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '258', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '198000', 'serum_creatinine': '1.4', 'serum_sodium': '129', 'sex': '1', 'smoking': '0', 'time': '235', 'DEATH_EVENT': '1'}
# {'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '1199', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '1', 'smoking': '1', 'time': '241', 'DEATH_EVENT': '1'}

# %%
# 9. Function to compute and return the IQR of ejection fraction and serum creatinine
def calculate_IQR(csv_data):
    ejection_fraction_values = []
    serum_creatinine_values = []

    for patient_id, details in csv_data.items():
        ejection_fraction = float(details["ejection_fraction"])
        serum_creatinine = float(details["serum_creatinine"])

        ejection_fraction_values.append(ejection_fraction)
        serum_creatinine_values.append(serum_creatinine)

    # Compute IQR for ejection fraction
    ejection_fraction_values.sort()
    ejection_fraction_q1 = ejection_fraction_values[int(0.25 * len(ejection_fraction_values))]
    ejection_fraction_q3 = ejection_fraction_values[int(0.75 * len(ejection_fraction_values))]
    ejection_fraction_IQR = ejection_fraction_q3 - ejection_fraction_q1

    # Compute IQR for serum creatinine
    serum_creatinine_values.sort()
    serum_creatinine_q1 = serum_creatinine_values[int(0.25 * len(serum_creatinine_values))]
    serum_creatinine_q3 = serum_creatinine_values[int(0.75 * len(serum_creatinine_values))]
    serum_creatinine_IQR = serum_creatinine_q3 - serum_creatinine_q1

    print(f"Interquartile Range (IQR) of Ejection Fraction: {ejection_fraction_IQR}")
    print(f"Interquartile Range (IQR) of Serum Creatinine: {serum_creatinine_IQR}")

calculate_IQR(csv_data)
# Out:
# Interquartile Range (IQR) of Ejection Fraction: 15.0
# Interquartile Range (IQR) of Serum Creatinine: 0.4999999999999999

# %%
#10. function to compute and return the sample variance of creatinine phosphokinase and serum sodium.
import statistics
def compute_variance(csv_data):
    # Helper function to calculate the sample variance
    def variance(data):
        return statistics.variance(data)

    # Lists to hold creatinine_phosphokinase and serum_sodium values
    creatinine_phosphokinase_values = []
    serum_sodium_values = []

    # Iterate through the csv_data and extract the relevant values
    for patient_id, details in csv_data.items():
        creatinine_phosphokinase_values.append(float(details["creatinine_phosphokinase"]))
        serum_sodium_values.append(float(details["serum_sodium"]))

    # Compute variance for both variables
    creatinine_phosphokinase_variance = variance(creatinine_phosphokinase_values)
    serum_sodium_variance = variance(serum_sodium_values)

    return {
        "creatinine_phosphokinase_variance": creatinine_phosphokinase_variance,
        "serum_sodium_variance": serum_sodium_variance
    }

compute_variance(csv_data)
# Out:
# {'creatinine_phosphokinase_variance': 941458.5714574308,
#  'serum_sodium_variance': 19.469955781015017}

# %%
#11.Function to save the  output of dead patients statistics into an external file in csv format.
 

import csv
from collections import Counter

def death_age_statistics(csv_data, output_file_path):
    sum_of_ages = 0
    count = 0
    ages = []

    # Filter data for those who died due to heart failure
    for patient_id, details in csv_data.items():
        age = float(details["age"])
        DEATH_EVENT = int(details["DEATH_EVENT"])
        if DEATH_EVENT == 1:  # Filter for those who died
            sum_of_ages += age
            count += 1
            ages.append(age)

    # Compute average age
    if count > 0:
        average_age = sum_of_ages / count
    else:
        average_age = 0

    # Calculate modal age
    age_frequency = Counter(ages)
    modal_age = age_frequency.most_common(1)[0][0] if age_frequency else None

    # Calculate median age
    ages.sort()
    y = len(ages)
    if y % 2 == 1:
        median_age = ages[y // 2]
    else:
        median_age = (ages[y // 2 - 1] + ages[y // 2]) / 2 if y > 0 else 0

    # Save the results to a CSV file
    with open(output_file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Statistics of dead people", "Value"])  # Write header row
        writer.writerow(["Average Age", average_age])
        writer.writerow(["Modal Age", modal_age])
        writer.writerow(["Median Age", median_age])

    

output_file_path = r"C:\Users\USER\Downloads\death_age_statistics1.csv"

death_age_statistics(csv_data, output_file_path)

# %%
# %%writefile querymodule.py
import csv
from collections import Counter
from csv_loader import load_csv_with_generated_ids
import statistics

file_path = r"C:\Users\USER\Downloads\heart+failure+clinical+records\heart_failure_clinical_records_dataset.csv"

csv_data = load_csv_with_generated_ids(file_path)


# 1. Function for computing the average age, modal age, and median age of those whose heart failure resulted in death
def death_age_statistics(csv_data):
    sum_of_ages = 0
    count = 0
    ages = []

    for patient_id, details in csv_data.items():
        age = float(details["age"])
        DEATH_EVENT = int(details["DEATH_EVENT"])
        if DEATH_EVENT == 1:  # Filter for those who died
            sum_of_ages += age
            count += 1
            ages.append(age)

    if count > 0:
        average_age = sum_of_ages / count
    else:
        average_age = 0

    # Calculate modal age
    age_frequency = Counter(ages)
    modal_age = age_frequency.most_common(1)[0][0] if age_frequency else None

    # Calculate median age
    ages.sort()
    y = len(ages)
    if y % 2 == 1:
        median_age = ages[y // 2]
    else:
        median_age = (ages[y // 2 - 1] + ages[y // 2]) / 2 if y > 0 else 0

    # Print the results
    print(f"Information on those who died due to heart failure:")
    print(f" Average Age: {average_age}")
    print(f"Modal Age: {modal_age}")
    print(f"Median Age: {median_age}")

death_age_statistics(csv_data)

# 2. Function for computing the average time taken for those whose heart failure did not result in death
def non_death_time_statistics(csv_data):
    total_time_taken = 0
    count = 0
    for patient_id, details in csv_data.items():
        time = int(details['time'])
        DEATH_EVENT = int(details["DEATH_EVENT"])
        if DEATH_EVENT == 0:  # Filter for those who survived
            total_time_taken += time
            count += 1

    if count > 0:
        average_time = total_time_taken / count
    else:
        average_time = 0

    # Print the result
    print(f"Average time for those whose heart failure did not result in death is {average_time}")

non_death_time_statistics(csv_data)

# 3. Function to compute median age, average age, and modal age of those with high blood pressure
def high_bp_statistics(csv_data):
    sum_of_ages = 0
    count = 0
    ages = []

    for patient_id, details in csv_data.items():
        age = float(details["age"])
        high_bp = int(details["high_blood_pressure"])
        if high_bp == 1:  # Filter for high blood pressure cases
            sum_of_ages += age
            count += 1
            ages.append(age)

    if count > 0:
        average_age = sum_of_ages / count
    else:
        average_age = 0

    # Calculate modal age
    age_frequency = Counter(ages)
    modal_age = age_frequency.most_common(1)[0][0] if age_frequency else None

    # Calculate median age
    ages.sort()
    y = len(ages)
    if y % 2 == 1:
        median_age = ages[y // 2]
    else:
        median_age = (ages[y // 2 - 1] + ages[y // 2]) / 2 if y > 0 else 0

    # Print the results
    print(f"Information on those who have high blood pressure:")
    print(f"Their average Age is {average_age}")
    print(f"Their modal Age is {modal_age}")
    print(f"Their Median Age is {median_age}")

high_bp_statistics(csv_data)

# 4. Function to compute median age, average age, and modal age of those with diabetes
def diabetes_statistics(csv_data):
    sum_of_ages = 0
    count = 0
    ages = []

    for patient_id, details in csv_data.items():
        age = float(details["age"])
        diabetes_status = int(details["diabetes"])
        if diabetes_status == 1:  # Filter for diabetes cases
            sum_of_ages += age
            count += 1
            ages.append(age)

    if count > 0:
        average_age = sum_of_ages / count
    else:
        average_age = 0

    # Calculate modal age
    age_frequency = Counter(ages)
    modal_age = age_frequency.most_common(1)[0][0] if age_frequency else None

    # Calculate median age
    ages.sort()
    y = len(ages)
    if y % 2 == 1:
        median_age = ages[y // 2]
    else:
        median_age = (ages[y // 2 - 1] + ages[y // 2]) / 2 if y > 0 else 0

    # Print the results
    print(f"Information of Diabetic patients")
    print(f"Their Average Ageis {average_age}")
    print(f"Their Modal Age is  {modal_age}")
    print(f"Their Median Age is {median_age}")

diabetes_statistics(csv_data)

# 5. Function to determine whether diabetes is linked to smoking and high blood pressure
def diabetes_smoking_highbp_link(csv_data):
    diabetes_smoking_highbp_count = 0
    diabetes_smoking_no_highbp_count = 0
    diabetes_no_smoking_highbp_count = 0
    diabetes_no_smoking_no_highbp_count = 0

    # Count occurrences
    for patient_id, details in csv_data.items():
        diabetes = int(details['diabetes'])
        smoking = int(details['smoking'])
        high_blood_pressure = int(details['high_blood_pressure'])

        if diabetes == 1 and smoking == 1 and high_blood_pressure == 1:
            diabetes_smoking_highbp_count += 1
        elif diabetes == 1 and smoking == 1 and high_blood_pressure == 0:
            diabetes_smoking_no_highbp_count += 1
        elif diabetes == 1 and smoking == 0 and high_blood_pressure == 1:
            diabetes_no_smoking_highbp_count += 1
        elif diabetes == 1 and smoking == 0 and high_blood_pressure == 0:
            diabetes_no_smoking_no_highbp_count += 1

    # Print the contingency table
    print(f"Link between diabetes, smoking, and high blood pressure:")
    print(f"Diabetes, Smoking, and High BP: {diabetes_smoking_highbp_count}")
    print(f"Diabetes, Smoking, No High BP: {diabetes_smoking_no_highbp_count}")
    print(f"Diabetes, No Smoking, High BP: {diabetes_no_smoking_highbp_count}")
    print(f"Diabetes, No Smoking, No High BP: {diabetes_no_smoking_no_highbp_count}")
    print(f"There is no significant relationship between diabetes,smoking and high blood pressure")
diabetes_smoking_highbp_link(csv_data)

# 6. Function to compute the average serum sodium of those with diabetes
def average_serum_sodium_diabetes(csv_data):
    total_sodium = 0
    count = 0
    for patient_id, details in csv_data.items():
        serum_sodium = float(details["serum_sodium"])
        diabetes_status = int(details["diabetes"])
        if diabetes_status == 1:  # Filter for diabetes cases
            total_sodium += serum_sodium
            count += 1

    if count > 0:
        average_sodium = total_sodium / count
    else:
        average_sodium = 0

    # Print the result
    print(f"The average Serum Sodium for those with diabetes is {average_sodium}")

average_serum_sodium_diabetes(csv_data)

# 7. Function to determine if anaemia is linked to smoking
def anaemia_smoking_link(csv_data):
    anaemia_smoking_count = 0
    anaemia_non_smoking_count = 0
    for patient_id, details in csv_data.items():
        anaemia = int(details["anaemia"])
        smoking = int(details["smoking"])

        if anaemia == 1 and smoking == 1:
            anaemia_smoking_count += 1
        elif anaemia == 1 and smoking == 0:
            anaemia_non_smoking_count += 1

    print(f"Link between anaemia and smoking:")
    print(f"Anaemia with smoking: {anaemia_smoking_count}")
    print(f"Anaemia without smoking: {anaemia_non_smoking_count}")
    print(f"This suggests anaemia is not linked to smoking")

anaemia_smoking_link(csv_data)

# 8. Function that returns anyone without high blood pressure that died of heart failure
def no_highbp_death(csv_data):
    for patient_id, details in csv_data.items():
        DEATH_EVENT = int(details["DEATH_EVENT"])
        high_blood_pressure = int(details["high_blood_pressure"])

        if DEATH_EVENT == 1 and high_blood_pressure == 0:
            print(details)

no_highbp_death(csv_data)

# 9. Function to compute and return the IQR of ejection fraction and serum creatinine
def calculate_IQR(csv_data):
    ejection_fraction_values = []
    serum_creatinine_values = []

    for patient_id, details in csv_data.items():
        ejection_fraction = float(details["ejection_fraction"])
        serum_creatinine = float(details["serum_creatinine"])

        ejection_fraction_values.append(ejection_fraction)
        serum_creatinine_values.append(serum_creatinine)

    # Compute IQR for ejection fraction
    ejection_fraction_values.sort()
    ejection_fraction_q1 = ejection_fraction_values[int(0.25 * len(ejection_fraction_values))]
    ejection_fraction_q3 = ejection_fraction_values[int(0.75 * len(ejection_fraction_values))]
    ejection_fraction_IQR = ejection_fraction_q3 - ejection_fraction_q1

    # Compute IQR for serum creatinine
    serum_creatinine_values.sort()
    serum_creatinine_q1 = serum_creatinine_values[int(0.25 * len(serum_creatinine_values))]
    serum_creatinine_q3 = serum_creatinine_values[int(0.75 * len(serum_creatinine_values))]
    serum_creatinine_IQR = serum_creatinine_q3 - serum_creatinine_q1

    print(f"Interquartile Range (IQR) of Ejection Fraction: {ejection_fraction_IQR}")
    print(f"Interquartile Range (IQR) of Serum Creatinine: {serum_creatinine_IQR}")

calculate_IQR(csv_data)

#10. function to compute and return the sample variance of creatinine phosphokinase and serum sodium.
def compute_variance(csv_data):
    # Helper function to calculate the sample variance
    def variance(data):\
        return statistics.variance(data)

    # Lists to hold creatinine_phosphokinase and serum_sodium values
    creatinine_phosphokinase_values = []
    serum_sodium_values = []

    # Iterate through the csv_data and extract the relevant values
    for patient_id, details in csv_data.items():
        creatinine_phosphokinase_values.append(float(details["creatinine_phosphokinase"]))
        serum_sodium_values.append(float(details["serum_sodium"]))

    # Compute variance for both variables
    creatinine_phosphokinase_variance = variance(creatinine_phosphokinase_values)
    serum_sodium_variance = variance(serum_sodium_values)

    return {
        "creatinine_phosphokinase_variance": creatinine_phosphokinase_variance,
        "serum_sodium_variance": serum_sodium_variance
    }

compute_variance(csv_data)
# Out:
# Overwriting querymodule.py

# %%
#%%writefile usermodule.py
def user_interface():# User module
    name = str(input("Enter your name: "))
    print(f"\nDear {name}, thank you for choosing to use this code.")
    print("It has been developed to provide valuable insights and streamline your work.")
    
    while True:
        print("\nWhat would you like to check?")
        print("Choose any option that fits what you want to check:")
        print("1: Check the average age, modal age, median age of those whose heart failure resulted in death")
        print("2: Check the average time for those whose heart failure did not result in death")
        print("3: Check the average age, modal age, median age of those with high blood pressure")
        print("4: Check the average age, modal age, median age of those with diabetes")
        print("5: Check if diabetes is linked to smoking and high blood pressure")
        print("6: Check the average serum sodium of those with diabetes")
        print("7: Check if anaemia is linked to smoking or not")
        print("8: Check for anyone without high blood pressure that died of heart failure")
        print("9: Check the IQRs of ejection fraction and serum creatinine")
        print("10: Check the sample variance of creatinine phosphokinase and serum sodium")
        
        choice = int(input("Enter your choice: "))
        
        # Ensure the csv_data is passed correctly to each function
        if choice == 1:
            from querymodule import death_age_statistics
            death_age_statistics(csv_data)  # Pass csv_data here
        elif choice == 2:
            from querymodule import non_death_time_statistics
            non_death_time_statistics(csv_data)  # Pass csv_data here
        elif choice == 3:
            from querymodule import high_bp_statistics
            high_bp_statistics(csv_data)  # Pass csv_data here
        elif choice == 4:
            from querymodule import diabetes_statistics
            diabetes_statistics(csv_data)  # Pass csv_data here
        elif choice == 5:
            from querymodule import diabetes_smoking_highbp_link
            diabetes_smoking_highbp_link(csv_data)  # Pass csv_data here
        elif choice == 6:
            from querymodule import average_serum_sodium_diabetes
            average_serum_sodium_diabetes(csv_data)  # Pass csv_data here
        elif choice == 7:
            from querymodule import anaemia_smoking_link
            anaemia_smoking_link(csv_data)  # Pass csv_data here
        elif choice == 8:
            from querymodule import no_highbp_death
            no_highbp_death(csv_data)  # Pass csv_data here
        elif choice == 9:
            from querymodule import calculate_IQR
            calculate_IQR(csv_data)  # Pass csv_data here
        elif choice == 10:
            from querymodule import compute_variance
            compute_variance(csv_data) 
        else:
            print("Enter a number between 1 and 10")
        
        
        # Ask if the user wants to continue
        continue_choice = input("Do you want to continue? (yes/no): ").lower()
        if continue_choice == 'no':
            print("Thank you for using the system. Goodbye!")
            break  # Exit the loop and end the program
        elif continue_choice != 'yes':
            print("Invalid input. Exiting the program.")
            break  # Exit the loop if the input is not 'yes' or 'no'
user_interface()
# Out:
# Enter your name: Zainab Olalere
#
# Dear Zainab Olalere, thank you for choosing to use this code.
# It has been developed to provide valuable insights and streamline your work.
#
# What would you like to check?
# Choose any option that fits what you want to check:
# 1: Check the average age, modal age, median age of those whose heart failure resulted in death
# 2: Check the average time for those whose heart failure did not result in death
# 3: Check the average age, modal age, median age of those with high blood pressure
# 4: Check the average age, modal age, median age of those with diabetes
# 5: Check if diabetes is linked to smoking and high blood pressure
# 6: Check the average serum sodium of those with diabetes
# 7: Check if anaemia is linked to smoking or not
# 8: Check for anyone without high blood pressure that died of heart failure
# 9: Check the IQRs of ejection fraction and serum creatinine
# 10: Check the sample variance of creatinine phosphokinase and serum sodium
# Enter your choice: 3
# Information on those who died due to heart failure:
#  Average Age: 65.21528125
# Modal Age: 60.0
# Median Age: 65.0
# Average time for those whose heart failure did not result in death is 158.3399014778325
# Information on those who have high blood pressure:
# Their average Age is 62.339685714285714
# Their modal Age is 70.0
# Their Median Age is 62.0
# Information of Diabetic patients
# Their Average Ageis 59.41867200000001
# Their Modal Age is  60.0
# Their Median Age is 60.0
# Link between diabetes, smoking, and high blood pressure:
# Diabetes, Smoking, and High BP: 11
# Diabetes, Smoking, No High BP: 19
# Diabetes, No Smoking, High BP: 32
# Diabetes, No Smoking, No High BP: 63
# There is no significant relationship between diabetes,smoking and high blood pressure
# The average Serum Sodium for those with diabetes is 136.16
# Link between anaemia and smoking:
# Anaemia with smoking: 34
# Anaemia without smoking: 95
# This suggests anaemia is not linked to smoking
# {'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '7861', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.1', 'serum_sodium': '136', 'sex': '1', 'smoking': '0', 'time': '6', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '146', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '162000', 'serum_creatinine': '1.3', 'serum_sodium': '129', 'sex': '1', 'smoking': '1', 'time': '7', 'DEATH_EVENT': '1'}
# {'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '111', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '210000', 'serum_creatinine': '1.9', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '7', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '160', 'diabetes': '1', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '327000', 'serum_creatinine': '2.7', 'serum_sodium': '116', 'sex': '0', 'smoking': '0', 'time': '8', 'DEATH_EVENT': '1'}
# {'age': '75', 'anaemia': '1', 'creatinine_phosphokinase': '246', 'diabetes': '0', 'ejection_fraction': '15', 'high_blood_pressure': '0', 'platelets': '127000', 'serum_creatinine': '1.2', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '10', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '315', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '454000', 'serum_creatinine': '1.1', 'serum_sodium': '131', 'sex': '1', 'smoking': '1', 'time': '10', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '157', 'diabetes': '0', 'ejection_fraction': '65', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.5', 'serum_sodium': '138', 'sex': '0', 'smoking': '0', 'time': '10', 'DEATH_EVENT': '1'}
# {'age': '45', 'anaemia': '1', 'creatinine_phosphokinase': '981', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '136000', 'serum_creatinine': '1.1', 'serum_sodium': '137', 'sex': '1', 'smoking': '0', 'time': '11', 'DEATH_EVENT': '1'}
# {'age': '82', 'anaemia': '1', 'creatinine_phosphokinase': '379', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '47000', 'serum_creatinine': '1.3', 'serum_sodium': '136', 'sex': '1', 'smoking': '0', 'time': '13', 'DEATH_EVENT': '1'}
# {'age': '87', 'anaemia': '1', 'creatinine_phosphokinase': '149', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '262000', 'serum_creatinine': '0.9', 'serum_sodium': '140', 'sex': '1', 'smoking': '0', 'time': '14', 'DEATH_EVENT': '1'}
# {'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '14', 'high_blood_pressure': '0', 'platelets': '166000', 'serum_creatinine': '0.8', 'serum_sodium': '127', 'sex': '1', 'smoking': '0', 'time': '14', 'DEATH_EVENT': '1'}
# {'age': '48', 'anaemia': '1', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '55', 'high_blood_pressure': '0', 'platelets': '87000', 'serum_creatinine': '1.9', 'serum_sodium': '121', 'sex': '0', 'smoking': '0', 'time': '15', 'DEATH_EVENT': '1'}
# {'age': '80', 'anaemia': '0', 'creatinine_phosphokinase': '148', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '149000', 'serum_creatinine': '1.9', 'serum_sodium': '144', 'sex': '1', 'smoking': '1', 'time': '23', 'DEATH_EVENT': '1'}
# {'age': '58', 'anaemia': '1', 'creatinine_phosphokinase': '60', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '153000', 'serum_creatinine': '5.8', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '26', 'DEATH_EVENT': '1'}
# {'age': '82', 'anaemia': '0', 'creatinine_phosphokinase': '70', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '200000', 'serum_creatinine': '1.2', 'serum_sodium': '132', 'sex': '1', 'smoking': '1', 'time': '26', 'DEATH_EVENT': '1'}
# {'age': '85', 'anaemia': '0', 'creatinine_phosphokinase': '23', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '0', 'platelets': '360000', 'serum_creatinine': '3', 'serum_sodium': '132', 'sex': '1', 'smoking': '0', 'time': '28', 'DEATH_EVENT': '1'}
# {'age': '69', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '228000', 'serum_creatinine': '3.5', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '1'}
# {'age': '90', 'anaemia': '1', 'creatinine_phosphokinase': '60', 'diabetes': '1', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '226000', 'serum_creatinine': '1', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '235', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '329000', 'serum_creatinine': '3', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '30', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '588', 'diabetes': '1', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '194000', 'serum_creatinine': '1.1', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '33', 'DEATH_EVENT': '1'}
# {'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '310000', 'serum_creatinine': '1.9', 'serum_sodium': '135', 'sex': '1', 'smoking': '1', 'time': '35', 'DEATH_EVENT': '1'}
# {'age': '57', 'anaemia': '1', 'creatinine_phosphokinase': '129', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '395000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '0', 'smoking': '0', 'time': '42', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '3964', 'diabetes': '1', 'ejection_fraction': '62', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '6.8', 'serum_sodium': '146', 'sex': '0', 'smoking': '0', 'time': '43', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '260', 'diabetes': '1', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '255000', 'serum_creatinine': '2.2', 'serum_sodium': '132', 'sex': '0', 'smoking': '1', 'time': '45', 'DEATH_EVENT': '1'}
# {'age': '95', 'anaemia': '1', 'creatinine_phosphokinase': '371', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '461000', 'serum_creatinine': '2', 'serum_sodium': '132', 'sex': '1', 'smoking': '0', 'time': '50', 'DEATH_EVENT': '1'}
# {'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '385000', 'serum_creatinine': '1', 'serum_sodium': '145', 'sex': '1', 'smoking': '0', 'time': '61', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '68', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '119000', 'serum_creatinine': '2.9', 'serum_sodium': '127', 'sex': '1', 'smoking': '1', 'time': '64', 'DEATH_EVENT': '1'}
# {'age': '42', 'anaemia': '1', 'creatinine_phosphokinase': '250', 'diabetes': '1', 'ejection_fraction': '15', 'high_blood_pressure': '0', 'platelets': '213000', 'serum_creatinine': '1.3', 'serum_sodium': '136', 'sex': '0', 'smoking': '0', 'time': '65', 'DEATH_EVENT': '1'}
# {'age': '72', 'anaemia': '1', 'creatinine_phosphokinase': '110', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '274000', 'serum_creatinine': '1', 'serum_sodium': '140', 'sex': '1', 'smoking': '1', 'time': '65', 'DEATH_EVENT': '1'}
# {'age': '70', 'anaemia': '0', 'creatinine_phosphokinase': '161', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '244000', 'serum_creatinine': '1.2', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '66', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '113', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '497000', 'serum_creatinine': '1.83', 'serum_sodium': '135', 'sex': '1', 'smoking': '0', 'time': '67', 'DEATH_EVENT': '1'}
# {'age': '85', 'anaemia': '0', 'creatinine_phosphokinase': '5882', 'diabetes': '0', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '243000', 'serum_creatinine': '1', 'serum_sodium': '132', 'sex': '1', 'smoking': '1', 'time': '72', 'DEATH_EVENT': '1'}
# {'age': '69', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '266000', 'serum_creatinine': '1.2', 'serum_sodium': '134', 'sex': '1', 'smoking': '1', 'time': '73', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '47', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '204000', 'serum_creatinine': '0.7', 'serum_sodium': '139', 'sex': '1', 'smoking': '1', 'time': '73', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '76', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '196000', 'serum_creatinine': '2.5', 'serum_sodium': '132', 'sex': '0', 'smoking': '0', 'time': '77', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '1', 'creatinine_phosphokinase': '154', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '210000', 'serum_creatinine': '1.7', 'serum_sodium': '135', 'sex': '1', 'smoking': '0', 'time': '82', 'DEATH_EVENT': '1'}
# {'age': '85', 'anaemia': '0', 'creatinine_phosphokinase': '129', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '306000', 'serum_creatinine': '1.2', 'serum_sodium': '132', 'sex': '1', 'smoking': '1', 'time': '90', 'DEATH_EVENT': '1'}
# {'age': '70', 'anaemia': '1', 'creatinine_phosphokinase': '143', 'diabetes': '0', 'ejection_fraction': '60', 'high_blood_pressure': '0', 'platelets': '351000', 'serum_creatinine': '1.3', 'serum_sodium': '137', 'sex': '0', 'smoking': '0', 'time': '90', 'DEATH_EVENT': '1'}
# {'age': '86', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '0', 'smoking': '0', 'time': '95', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '40', 'high_blood_pressure': '0', 'platelets': '217000', 'serum_creatinine': '3.7', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '96', 'DEATH_EVENT': '1'}
# {'age': '80', 'anaemia': '0', 'creatinine_phosphokinase': '805', 'diabetes': '0', 'ejection_fraction': '38', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.1', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '109', 'DEATH_EVENT': '1'}
# {'age': '75', 'anaemia': '1', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '225000', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '113', 'DEATH_EVENT': '1'}
# {'age': '50', 'anaemia': '1', 'creatinine_phosphokinase': '2334', 'diabetes': '1', 'ejection_fraction': '35', 'high_blood_pressure': '0', 'platelets': '75000', 'serum_creatinine': '0.9', 'serum_sodium': '142', 'sex': '0', 'smoking': '0', 'time': '126', 'DEATH_EVENT': '1'}
# {'age': '45', 'anaemia': '0', 'creatinine_phosphokinase': '2442', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '334000', 'serum_creatinine': '1.1', 'serum_sodium': '139', 'sex': '1', 'smoking': '0', 'time': '129', 'DEATH_EVENT': '1'}
# {'age': '59', 'anaemia': '0', 'creatinine_phosphokinase': '66', 'diabetes': '1', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '70000', 'serum_creatinine': '2.4', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '135', 'DEATH_EVENT': '1'}
# {'age': '59', 'anaemia': '1', 'creatinine_phosphokinase': '176', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '221000', 'serum_creatinine': '1', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '150', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '0', 'creatinine_phosphokinase': '395', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '265000', 'serum_creatinine': '1.2', 'serum_sodium': '136', 'sex': '1', 'smoking': '1', 'time': '154', 'DEATH_EVENT': '1'}
# {'age': '58', 'anaemia': '1', 'creatinine_phosphokinase': '145', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '219000', 'serum_creatinine': '1.2', 'serum_sodium': '137', 'sex': '1', 'smoking': '1', 'time': '170', 'DEATH_EVENT': '1'}
# {'age': '60.667', 'anaemia': '1', 'creatinine_phosphokinase': '104', 'diabetes': '1', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '389000', 'serum_creatinine': '1.5', 'serum_sodium': '136', 'sex': '1', 'smoking': '0', 'time': '171', 'DEATH_EVENT': '1'}
# {'age': '50', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '50', 'high_blood_pressure': '0', 'platelets': '153000', 'serum_creatinine': '0.6', 'serum_sodium': '134', 'sex': '0', 'smoking': '0', 'time': '172', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '1896', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '365000', 'serum_creatinine': '2.1', 'serum_sodium': '144', 'sex': '0', 'smoking': '0', 'time': '172', 'DEATH_EVENT': '1'}
# {'age': '77', 'anaemia': '1', 'creatinine_phosphokinase': '418', 'diabetes': '0', 'ejection_fraction': '45', 'high_blood_pressure': '0', 'platelets': '223000', 'serum_creatinine': '1.8', 'serum_sodium': '145', 'sex': '1', 'smoking': '0', 'time': '180', 'DEATH_EVENT': '1'}
# {'age': '73', 'anaemia': '0', 'creatinine_phosphokinase': '582', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '1', 'smoking': '0', 'time': '198', 'DEATH_EVENT': '1'}
# {'age': '60', 'anaemia': '0', 'creatinine_phosphokinase': '166', 'diabetes': '0', 'ejection_fraction': '30', 'high_blood_pressure': '0', 'platelets': '62000', 'serum_creatinine': '1.7', 'serum_sodium': '127', 'sex': '0', 'smoking': '0', 'time': '207', 'DEATH_EVENT': '1'}
# {'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '2017', 'diabetes': '0', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '314000', 'serum_creatinine': '1.1', 'serum_sodium': '138', 'sex': '1', 'smoking': '0', 'time': '214', 'DEATH_EVENT': '1'}
# {'age': '65', 'anaemia': '1', 'creatinine_phosphokinase': '258', 'diabetes': '1', 'ejection_fraction': '25', 'high_blood_pressure': '0', 'platelets': '198000', 'serum_creatinine': '1.4', 'serum_sodium': '129', 'sex': '1', 'smoking': '0', 'time': '235', 'DEATH_EVENT': '1'}
# {'age': '55', 'anaemia': '0', 'creatinine_phosphokinase': '1199', 'diabetes': '0', 'ejection_fraction': '20', 'high_blood_pressure': '0', 'platelets': '263358.03', 'serum_creatinine': '1.83', 'serum_sodium': '134', 'sex': '1', 'smoking': '1', 'time': '241', 'DEATH_EVENT': '1'}
# Interquartile Range (IQR) of Ejection Fraction: 15.0
# Interquartile Range (IQR) of Serum Creatinine: 0.4999999999999999
# Information on those who have high blood pressure:
# Their average Age is 62.339685714285714
# Their modal Age is 70.0
# Their Median Age is 62.0
# Do you want to continue? (yes/no): yes
#
# What would you like to check?
# Choose any option that fits what you want to check:
# 1: Check the average age, modal age, median age of those whose heart failure resulted in death
# 2: Check the average time for those whose heart failure did not result in death
# 3: Check the average age, modal age, median age of those with high blood pressure
# 4: Check the average age, modal age, median age of those with diabetes
# 5: Check if diabetes is linked to smoking and high blood pressure
# 6: Check the average serum sodium of those with diabetes
# 7: Check if anaemia is linked to smoking or not
# 8: Check for anyone without high blood pressure that died of heart failure
# 9: Check the IQRs of ejection fraction and serum creatinine
# 10: Check the sample variance of creatinine phosphokinase and serum sodium
# Enter your choice: 2
# Average time for those whose heart failure did not result in death is 158.3399014778325
# Do you want to continue? (yes/no): yes
#
# What would you like to check?
# Choose any option that fits what you want to check:
# 1: Check the average age, modal age, median age of those whose heart failure resulted in death
# 2: Check the average time for those whose heart failure did not result in death
# 3: Check the average age, modal age, median age of those with high blood pressure
# 4: Check the average age, modal age, median age of those with diabetes
# 5: Check if diabetes is linked to smoking and high blood pressure
# 6: Check the average serum sodium of those with diabetes
# 7: Check if anaemia is linked to smoking or not
# 8: Check for anyone without high blood pressure that died of heart failure
# 9: Check the IQRs of ejection fraction and serum creatinine
# 10: Check the sample variance of creatinine phosphokinase and serum sodium
# Enter your choice: 7
# Link between anaemia and smoking:
# Anaemia with smoking: 34
# Anaemia without smoking: 95
# This suggests anaemia is not linked to smoking
# Do you want to continue? (yes/no): yes
#
# What would you like to check?
# Choose any option that fits what you want to check:
# 1: Check the average age, modal age, median age of those whose heart failure resulted in death
# 2: Check the average time for those whose heart failure did not result in death
# 3: Check the average age, modal age, median age of those with high blood pressure
# 4: Check the average age, modal age, median age of those with diabetes
# 5: Check if diabetes is linked to smoking and high blood pressure
# 6: Check the average serum sodium of those with diabetes
# 7: Check if anaemia is linked to smoking or not
# 8: Check for anyone without high blood pressure that died of heart failure
# 9: Check the IQRs of ejection fraction and serum creatinine
# 10: Check the sample variance of creatinine phosphokinase and serum sodium
# Enter your choice: 12
# Enter a number between 1 and 10
# Do you want to continue? (yes/no): no
# Thank you for using the system. Goodbye!
